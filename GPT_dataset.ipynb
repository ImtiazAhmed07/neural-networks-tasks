# %% [markdown]
# <a href="https://colab.research.google.com/github/ImtiazAhmed07/neural-networks-tasks/blob/main/GPT_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# Hyperparameters
batch_size = 16
block_size = 32
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
eval_iters = 200
n_embd = 128  # Increased embedding size for better capacity
n_head = 4
n_layer = 4
dropout = 0.1  # Added dropout
device = 'cuda' if torch.cuda.is_available() else 'cpu'

torch.manual_seed(1337)
if device == 'cuda':
    torch.cuda.manual_seed(1337)
    torch.backends.cudnn.benchmark = True

# Load data
with open('/content/Harry Potter and the Sorcerers Stone.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# Create character mappings
chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

# Prepare data
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

# Data loader
def get_batch(split):
    data_split = train_data if split == 'train' else val_data
    ix = torch.randint(len(data_split) - block_size, (batch_size,))
    x = torch.stack([data_split[i:i+block_size] for i in ix])
    y = torch.stack([data_split[i+1:i+block_size+1] for i in ix])
    return x.to(device), y.to(device)

@torch.no_grad()
def estimate_loss():
    model.eval()
    losses = {'train': 0, 'val': 0}
    for split in ['train', 'val']:
        for _ in range(eval_iters):
            X, Y = get_batch(split)
            _, loss = model(X, Y)
            losses[split] += loss.item()
        losses[split] /= eval_iters
    model.train()
    return losses

class Head(nn.Module):
    """One head of self-attention."""
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        v = self.value(x)
        wei = q @ k.transpose(-2, -1) * (C ** -0.5)
        mask = torch.tril(torch.ones(T, T, device=device))
        wei = wei.masked_fill(mask == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        return wei @ v

class MultiHeadAttention(nn.Module):
    """Multiple heads of self-attention in parallel."""
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    """Feed-forward network."""
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),  # Changed to GELU
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """Transformer block."""
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))  # Residual connection
        x = x + self.ffwd(self.ln2(x))  # Residual connection
        return x

class BigramLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(
            *[Block(n_embd, n_head) for _ in range(n_layer)]
        )
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

        # Weight tying
        self.lm_head.weight = self.token_embedding_table.weight

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)  # (B, T, C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))  # (T, C)
        x = tok_emb + pos_emb  # (B, T, C)
        x = self.blocks(x)  # (B, T, C)
        x = self.ln_f(x)  # (B, T, C)
        logits = self.lm_head(x)  # (B, T, vocab_size)
        if targets is None:
            return logits, None
        logits = logits.view(-1, vocab_size)
        targets = targets.view(-1)
        loss = F.cross_entropy(logits, targets)
        return logits, loss

    @torch.no_grad()
    def generate(self, idx, max_new_tokens):
        model.eval()
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        model.train()
        return idx

model = BigramLanguageModel().to(device)
print(f"{sum(p.numel() for p in model.parameters())/1e6:.2f}M parameters")

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=1e-2)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_iters)
scaler = torch.cuda.amp.GradScaler() if device == 'cuda' else None

for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"Step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    xb, yb = get_batch('train')
    if scaler:
        with torch.cuda.amp.autocast():
            _, loss = model(xb, yb)
        optimizer.zero_grad(set_to_none=True)
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()
    else:
        _, loss = model(xb, yb)
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
    scheduler.step()

# Generate text
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(model.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.81M parameters
# Step 0: train loss 82.7160, val loss 82.6431
# Step 100: train loss 2.6282, val loss 2.6453
# Step 200: train loss 2.5260, val loss 2.5208
# Step 300: train loss 2.3685, val loss 2.3445
# Step 400: train loss 2.2527, val loss 2.2293
# Step 500: train loss 2.1898, val loss 2.1724
# Step 600: train loss 2.1372, val loss 2.1235
# Step 700: train loss 2.0881, val loss 2.0831
# Step 800: train loss 2.0382, val loss 2.0169
# Step 900: train loss 1.9953, val loss 1.9859
# Step 1000: train loss 1.9858, val loss 1.9932
# Step 1100: train loss 1.9425, val loss 1.9316
# Step 1200: train loss 1.9213, val loss 1.9210
# Step 1300: train loss 1.8853, val loss 1.8957
# Step 1400: train loss 1.8527, val loss 1.8505
# Step 1500: train loss 1.8322, val loss 1.8536
# Step 1600: train loss 1.8340, val loss 1.8413
# Step 1700: train loss 1.8120, val loss 1.8238
# Step 1800: train loss 1.7890, val loss 1.7958
# Step 1900: train loss 1.7705, val loss 1.7953
# Step 2000: train loss 1.7608, val loss 1.7657
# Step 2100: train loss 1.7316, val loss 1.7606
# Step 2200: train loss 1.7313, val loss 1.7425
# Step 2300: train loss 1.7201, val loss 1.7360
# Step 2400: train loss 1.6943, val loss 1.7104
# Step 2500: train loss 1.7105, val loss 1.7048
# Step 2600: train loss 1.6752, val loss 1.6997
# Step 2700: train loss 1.6763, val loss 1.6870
# Step 2800: train loss 1.6787, val loss 1.6788
# Step 2900: train loss 1.6622, val loss 1.6871
# Step 3000: train loss 1.6536, val loss 1.6624
# Step 3100: train loss 1.6519, val loss 1.6648
# Step 3200: train loss 1.6445, val loss 1.6568
# Step 3300: train loss 1.6276, val loss 1.6437
# Step 3400: train loss 1.6252, val loss 1.6366
# Step 3500: train loss 1.6231, val loss 1.6377
# Step 3600: train loss 1.6069, val loss 1.6325
# Step 3700: train loss 1.6121, val loss 1.6315
# Step 3800: train loss 1.6110, val loss 1.6173
# Step 3900: train loss 1.6142, val loss 1.6182
# Step 4000: train loss 1.5938, val loss 1.6187
# Step 4100: train loss 1.5917, val loss 1.6121
# Step 4200: train loss 1.5856, val loss 1.6154
# Step 4300: train loss 1.5904, val loss 1.6120
# Step 4400: train loss 1.5911, val loss 1.6160
# Step 4500: train loss 1.5907, val loss 1.6061
# Step 4600: train loss 1.5826, val loss 1.6040
# Step 4700: train loss 1.5827, val loss 1.5981
# Step 4800: train loss 1.5872, val loss 1.6140
# Step 4900: train loss 1.5918, val loss 1.5939
# Step 4999: train loss 1.5833, val loss 1.6034
#
# FOnape tistand, when hown thes, oul so ind dayster.
#
# â€œConâ€™t mion,â€ he said dent. â€œA vuse, â€œLoCwany right a graid Dudley!â€ heâ€™d theree, grom it?â€
#
# â€œHolking up!â€
#
# At a weal drornow, head had ever roplape, jevery feame of have Professon Mr. â€œWho,â€ have broom Dudleys, manisfe to Mat as we ball into he sof them. Fit youâ€™ll off the backraing was the oad ouswe. And it Harry wand Uncle had connew as what posse ting not manâ€™ sent of thouse agrow he dand Harry preain flyone if?â€
#
# At have somenting ever of inno with He.
#
# â€œNeville weâ€™d jus the that a hel, weyâ€™s said no Hagrid know othe with brone heâ€™d greatch;s Alch. â€œThenâ€™ the looking expect befor, cans lot wouse hearced teave Fornowind as onsteagh, ho famt was weare.â€¦ thing the wendre back a tandled recause, a backy been in in hor reates neving to rejockaunt the uncle bout lighbat was in you you commore could on up.
#
# â€œOiryâ€™nly heâ€™ve whatâ€™s they a bed â€œSSay goind toâ€™s istor, saying ats a dry jumped. Harry swuffly to the down of do had Dumbred header wouldnâ€™ ween you turnow the coll therly whing not face, her in of thin Potunion Dudleys Rone Ta schat oard as dowatcht stare and belt one toâ€™d be got Nors al pish â€” will Arough an a blays time teat, the of it a to at likeforcas ea to a ling resk.
#
# Blight eik Gringot rest showls, ich divions. Harry wond had spected and they tolled and low, but that tep on themore magon pust firrang. â€œGonard you mone too, the his his parles, a said that und. He â€” ground. The in dissesel â€” Dumberedore in to know a sinrough,â€ Ron Harry parted they Hogwared the good on one. I tause hurheâ€™d knocked to with the eves. There ever clathing rontrer in takeve looking to dow the was sumplicuared, there. He gany he pards-made creace. Decoul, â€œwhen rew thave been, phat yound do nitch if wited you dight the cloard by a scup. And the sot the plack of a nime they in arme, whilving Ever.
#
# â€œItâ€™s just moved at Peturidle was somethookstoping s
